# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel("Satislar.xlsx")
data
# Out:
#     Aylar  Satislar
# 0       8      1110
# 1      11      1200
# 2      12      1232
# 3      14      1576
# 4      15      1748
# 5      16      1777
# 6      18      1879
# 7      19      2010
# 8      21      2100
# 9      24      2210
# 10     25      2489
# 11     28      2442
# 12     33      2678
# 13     35      2789
# 14     37      2891
# 15     39      3200
# 16     44      3321
# 17     47      3343
# 18     48      3354
# 19     51      3500
# 20     52      3722
# 21     55      4000
# 22     59      4433

# %%
sns.scatterplot(x="Aylar",y="Satislar",data=data)
# Out:
# <Axes: xlabel='Aylar', ylabel='Satislar'>

# %%
aylar = data[["Aylar"]]

# %%
satis = data[["Satislar"]]

# %%
satis2 = data.iloc[:,:1].values

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(aylar,satis,test_size=0.33,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
X_train = sc.fit_transform(x_train)
X_test = sc.fit_transform(x_test)

Y_train = sc.fit_transform(y_train)
Y_test = sc.fit_transform(y_test)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
x_train = x_train.sort_index()
y_train = y_train.sort_index()
tahmin = lr.predict(x_test)

# %%
plt.scatter(x_train,y_train)
plt.plot(x_test,tahmin)
plt.title("Aylara göre satislar")
# Out:
# Text(0.5, 1.0, 'Aylara göre satislar')
