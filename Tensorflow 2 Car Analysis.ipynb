# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings 
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("ford.csv")
df.head()
# Out:
#      model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0   Fiesta  2017  12000    Automatic    15944   Petrol  150  57.7         1.0
# 1    Focus  2018  14000       Manual     9083   Petrol  150  57.7         1.0
# 2    Focus  2017  13000       Manual    12456   Petrol  150  57.7         1.0
# 3   Fiesta  2019  17500       Manual    10460   Petrol  145  40.3         1.5
# 4   Fiesta  2019  16500    Automatic     1482   Petrol  145  48.7         1.0

# %%
df.describe()
# Out:
#                year         price        mileage           tax           mpg  \
# count  17965.000000  17965.000000   17965.000000  17965.000000  17965.000000
# mean    2016.866574  12279.756415   23363.630504    113.334539     57.906991
# std        2.050346   4741.382606   19472.114690     62.010438     10.125977
# min     1996.000000    495.000000       1.000000      0.000000     20.800000
# 25%     2016.000000   8999.000000    9987.000000     30.000000     52.300000
# 50%     2017.000000  11291.000000   18243.000000    145.000000     58.900000
# 75%     2018.000000  15299.000000   31064.000000    145.000000     65.700000
# max     2060.000000  54995.000000  177644.000000    580.000000    201.800000
#
#          engineSize
# count  17965.000000
# mean       1.350827
# std        0.432371
# min        0.000000
# 25%        1.000000
# 50%        1.200000
# 75%        1.500000
# max        5.000000

# %%
df.isnull().sum()
# Out:
# model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64

# %%
plt.figure(figsize=(7,5))
sns.distplot(df["price"])
# Out:
# <Axes: xlabel='price', ylabel='Density'>

# %%
df.corr()
# Out:
#                 year     price   mileage       tax       mpg  engineSize
# year        1.000000  0.635994 -0.707899  0.298457 -0.022969   -0.137358
# price       0.635994  1.000000 -0.530727  0.406821 -0.346427    0.411156
# mileage    -0.707899 -0.530727  1.000000 -0.260550  0.120077    0.215001
# tax         0.298457  0.406821 -0.260550  1.000000 -0.503013    0.184311
# mpg        -0.022969 -0.346427  0.120077 -0.503013  1.000000   -0.260527
# engineSize -0.137358  0.411156  0.215001  0.184311 -0.260527    1.000000

# %%
df.corr()["price"].sort_values() #!!!!!
# Out:
# mileage      -0.530727
# mpg          -0.346427
# tax           0.406821
# engineSize    0.411156
# year          0.635994
# price         1.000000
# Name: price, dtype: float64

# %%
sns.scatterplot(x="price",y="mileage",data=df)
# Out:
# <Axes: xlabel='price', ylabel='mileage'>

# %%
df.sort_values("price",ascending=False).head(20)
# Out:
#           model  year  price transmission  mileage fuelType  tax   mpg  \
# 11912     Focus  2018  54995       Manual    11000   Petrol  145  36.7
# 11913   Mustang  2017  49999       Manual    21575   Petrol  145  20.9
# 11910   Mustang  2017  48999    Automatic     7546   Petrol  145  23.5
# 17866   Mustang  2020  48000       Manual       50   Petrol  145  23.9
# 12613   Mustang  2019  45250    Automatic     2500   Petrol  145  22.1
# 10901   Mustang  2020  42999       Manual       10   Petrol  145  23.7
# 12996   Mustang  2019  42500    Automatic      226   Petrol  145  22.1
# 302     Mustang  2020  42489    Automatic     3500   Petrol  145  22.1
# 13431   Mustang  2019  42000    Semi-Auto      756   Petrol  150  22.6
# 12600   Mustang  2020  41000       Manual      100   Petrol  145  22.8
# 9695    Mustang  2019  41000    Semi-Auto      678   Petrol  145  22.1
# 10736   Mustang  2019  40495    Automatic     2000   Petrol  145  22.1
# ...

# %% [markdown]
# "If you take 99% of a data, that data will become better!"

# %%
len(df)*0.01 # -> Omitting Data
# Out:
# 179.65

# %%
PercentedDf = df.sort_values("price",ascending=False).iloc[180:] 
PercentedDf
# Out:
#          model  year  price transmission  mileage fuelType  tax   mpg  \
# 4374    Galaxy  2019  26430       Manual     9129   Diesel  145  55.4
# 3328    Galaxy  2019  26360       Manual     2725   Diesel  145  55.4
# 11191    Focus  2019  26299       Manual     3764   Petrol  145  34.5
# 13824   Mondeo  2020  26290    Automatic        7   Hybrid  135  47.1
# 3704     Focus  2019  26250       Manual     3775   Petrol  145  34.5
# ...        ...   ...    ...          ...      ...      ...  ...   ...
# 16704   Fiesta  2008    694       Manual    82020   Petrol  145  47.1
# 14222   Mondeo  2005    675       Manual    97000   Diesel  205  48.7
# 16904    Focus  2005    675       Manual   121000   Petrol  235  39.8
# 16811   Mondeo  2005    675       Manual   108000   Petrol  260  36.2
# 17103    Focus  2003    495       Manual   177644   Petrol  200  41.5
#
#        engineSize
# 4374          2.0
# 3328          2.0
# 11191         2.3
# 13824         2.0
# 3704          2.3
# ...

# %%
PercentedDf.describe()
# Out:
#                year         price        mileage           tax           mpg  \
# count  17785.000000  17785.000000   17785.000000  17785.000000  17785.000000
# mean    2016.847399  12084.037728   23538.842789    112.832724     58.083497
# std        2.049816   4316.442646   19482.288496     61.557371      9.581964
# min     1996.000000    495.000000       1.000000      0.000000     23.500000
# 25%     2016.000000   8998.000000   10111.000000     30.000000     53.300000
# 50%     2017.000000  11200.000000   18442.000000    145.000000     58.900000
# 75%     2018.000000  15000.000000   31265.000000    145.000000     65.700000
# max     2060.000000  26430.000000  177644.000000    570.000000     88.300000
#
#          engineSize
# count  17785.000000
# mean       1.336373
# std        0.389854
# min        0.000000
# 25%        1.000000
# 50%        1.200000
# 75%        1.500000
# max        5.000000

# %%
plt.figure(figsize=(7,5))
sns.distplot(PercentedDf["price"])
# Out:
# <Axes: xlabel='price', ylabel='Density'>

# %%
df.groupby("year").mean()["price"]
# Out:
# year
# 1996     3000.000000
# 1998     2699.000000
# 2000     1995.000000
# 2002     1928.333333
# 2003     2063.000000
# 2004     1436.000000
# 2005     1593.000000
# 2006     2202.615385
# 2007     2603.562500
# 2008     2598.894737
# 2009     3719.725275
# 2010     4058.253731
# 2011     5022.478723
# 2012     5680.930435
# 2013     6703.940887
# 2014     7541.874534
# 2015     8778.168252
# 2016    10665.668812
# 2017    11965.689853
# 2018    13157.894619
# 2019    17176.449280
# 2020    20819.872093
# 2060     6495.000000
# Name: price, dtype: float64

# %%
PercentedDf.groupby("year").mean()["price"]
# Out:
# year
# 1996     3000.000000
# 1998     2699.000000
# 2000     1995.000000
# 2002     1928.333333
# 2003     2063.000000
# 2004     1436.000000
# 2005     1593.000000
# 2006     2202.615385
# 2007     2603.562500
# 2008     2598.894737
# 2009     3719.725275
# 2010     4058.253731
# 2011     5022.478723
# 2012     5680.930435
# 2013     6703.940887
# 2014     7541.874534
# 2015     8778.168252
# 2016    10636.349377
# 2017    11899.573071
# 2018    13042.962387
# 2019    16692.369615
# 2020    19209.800866
# 2060     6495.000000
# Name: price, dtype: float64

# %%
df[df.year != 2060].groupby("year").mean()["price"]
# Out:
# year
# 1996     3000.000000
# 1998     2699.000000
# 2000     1995.000000
# 2002     1928.333333
# 2003     2063.000000
# 2004     1436.000000
# 2005     1593.000000
# 2006     2202.615385
# 2007     2603.562500
# 2008     2598.894737
# 2009     3719.725275
# 2010     4058.253731
# 2011     5022.478723
# 2012     5680.930435
# 2013     6703.940887
# 2014     7541.874534
# 2015     8778.168252
# 2016    10665.668812
# 2017    11965.689853
# 2018    13157.894619
# 2019    17176.449280
# 2020    20819.872093
# Name: price, dtype: float64

# %%
PercentedDf = PercentedDf[PercentedDf.year != 2060] # Year: 2060?

# %%
PercentedDf = PercentedDf.drop(["fuelType","model","transmission"],axis=1) 
# Categorical Data Omitting

# %%
y = PercentedDf["price"].values
x = PercentedDf.drop("price",axis=1).values

# %%
x
# Out:
# array([[2.01900e+03, 9.12900e+03, 1.45000e+02, 5.54000e+01, 2.00000e+00],
#        [2.01900e+03, 2.72500e+03, 1.45000e+02, 5.54000e+01, 2.00000e+00],
#        [2.01900e+03, 3.76400e+03, 1.45000e+02, 3.45000e+01, 2.30000e+00],
#        ...,
#        [2.00500e+03, 1.21000e+05, 2.35000e+02, 3.98000e+01, 2.00000e+00],
#        [2.00500e+03, 1.08000e+05, 2.60000e+02, 3.62000e+01, 1.80000e+00],
#        [2.00300e+03, 1.77644e+05, 2.00000e+02, 4.15000e+01, 1.60000e+00]])

# %%
y
# Out:
# array([26430, 26360, 26299, ...,   675,   675,   495], dtype=int64)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3, 
                                                    random_state=10)

# %%
len(x_train)
# Out:
# 12448

# %%
len(x_test)
# Out:
# 5336

# %%
from sklearn.preprocessing import MinMaxScaler
scaler= MinMaxScaler()

# %%
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model =  Sequential()

model.add(Dense(12,activation="relu"))
model.add(Dense(12,activation="relu"))
model.add(Dense(12,activation="relu"))
model.add(Dense(12,activation="relu"))

model.add(Dense(1))
model.compile(optimizer="adam",loss="mse")

# %%
model.fit(x = x_train, y = y_train,
          validation_data=(x_test,y_test),batch_size=250,epochs=300)
# Out:
# Epoch 1/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 165931840.0000 - val_loss: 164480592.0000
# Epoch 2/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 163701744.0000 - val_loss: 164375552.0000
# Epoch 3/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 164743088.0000 - val_loss: 163741472.0000
# Epoch 4/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 164003552.0000 - val_loss: 161170960.0000
# Epoch 5/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 161645968.0000 - val_loss: 153465664.0000
# Epoch 6/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 150445600.0000 - val_loss: 135284464.0000
# Epoch 7/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 127580928.0000 - val_loss: 102443008.0000
# Epoch 8/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 91933152.0000 - val_loss: 60124244.0000
# Epoch 9/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 51169424.0000 - val_loss: 28526098.0000
# Epoch 10/300
# ...

# %%
lost_data = pd.DataFrame(model.history.history)
lost_data.plot()
# Out:
# <Axes: >

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
predict_array = model.predict(x_test)
predict_array
# Out:
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# array([[10060.6045],
#        [14252.5625],
#        [11398.136 ],
#        ...,
#        [10521.17  ],
#        [13939.265 ],
#        [10073.41  ]], dtype=float32)

# %%
mean_absolute_error(y_test, predict_array)
# Out:
# 1460.2145864552465

# %%
plt.scatter(y_test,predict_array)
plt.plot(y_test,y_test,"r-*")

# %%
PercentedDf.iloc[44]
# Out:
# year           2019.0
# price         25500.0
# mileage        3011.0
# tax             145.0
# mpg              34.5
# engineSize        2.3
# Name: 982, dtype: float64

# %%
newcarseries = PercentedDf.drop("price",axis=1).iloc[44]
newcarseries = scaler.transform(newcarseries.values.reshape(-1,5))

# %%
model.predict(newcarseries)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# array([[24582.361]], dtype=float32)

# %%
from sklearn.metrics import r2_score

y_pred = predict_array

# Calculate R² score
r2 = r2_score(y_test, y_pred)
r2
# Out:
# 0.7941510677337646
